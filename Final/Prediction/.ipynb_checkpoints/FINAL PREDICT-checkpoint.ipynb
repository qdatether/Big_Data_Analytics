# %% [markdown]
# # VOLUME

# %% [markdown]
# ## Imports & Paths

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis

PATH_DATA  = r"C:/Users/nhokk/Downloads/FINAL DATASET.xlsx"
PATH_PMIME = r"C:/Users/nhokk/Downloads/PMIME_features_for_python.csv"
PATH_CGCI  = r"C:/Users/nhokk/Downloads/cgci_node_scores_top20vol_2021_2024.csv"

# %% [markdown]
# ## Load raw data + basic cleaning

# %%
df_raw = pd.read_excel(PATH_DATA)
df = df_raw.copy()
df.columns = [c.lower() for c in df.columns]

df["time"] = pd.to_datetime(df["time"])
df["symbol"] = df["symbol"].astype(str).str.upper()

# thời gian 2021-03-24 -> 2024-12-31
df = df[(df["time"] >= "2021-03-24") & (df["time"] < "2025-01-01")].copy()

# loại index và ROS
exclude = {"VNINDEX","VN30","ROS"}
df = df[~df["symbol"].isin(exclude)].copy()

# remove duplicates key
df = df.drop_duplicates(subset=["time","symbol"]).copy()

# top 20 theo total volume
top20 = (df.groupby("symbol")["volume"].sum().sort_values(ascending=False).head(20))
top20_symbols = top20.index.tolist()
df = df[df["symbol"].isin(top20_symbols)].copy()

print("✅ Base df:", df.shape)
print("✅ Top20 symbols:", top20_symbols)
print("✅ Date range:", df["time"].min(), "->", df["time"].max())
# Out:
# ✅ Base df: (18917, 9)
# ✅ Top20 symbols: ['HPG', 'STB', 'SHB', 'SSI', 'VPB', 'NVL', 'MBB', 'TCB', 'TCH', 'CTG', 'LPB', 'PDR', 'TPB', 'ACB', 'VHM', 'VRE', 'HDB', 'MWG', 'EIB', 'VIB']
# ✅ Date range: 2021-03-24 00:00:00 -> 2024-12-31 00:00:00

# %% [markdown]
# ## Technical features

# %%
prices = df.pivot(index="time", columns="symbol", values="close").sort_index()
prices = prices[top20_symbols].copy()
log_p = np.log(prices)

ret1 = log_p.diff().add_prefix("ret1_")
ret5 = (log_p.shift(-5) - log_p).add_prefix("y5_")   # TARGET (forward 5d log-return)

mom5  = log_p.diff(5).add_prefix("mom5_")
mom10 = log_p.diff(10).add_prefix("mom10_")
mom20 = log_p.diff(20).add_prefix("mom20_")

ma7  = ret1.rolling(7).mean().add_prefix("ma7_")
ma14 = ret1.rolling(14).mean().add_prefix("ma14_")
ma21 = ret1.rolling(21).mean().add_prefix("ma21_")

vol7  = ret1.rolling(7).std().add_prefix("vol7_")
vol14 = ret1.rolling(14).std().add_prefix("vol14_")
vol21 = ret1.rolling(21).std().add_prefix("vol21_")

vol_ratio = (vol7 / (vol21 + 1e-8))
vol_ratio.columns = [c.replace("vol7_", "volratio_") for c in vol_ratio.columns]

def rolling_apply(df_in, w, func, pre):
    out = pd.DataFrame(index=df_in.index, columns=df_in.columns, dtype="float64")
    for c in df_in.columns:
        out[c] = df_in[c].rolling(w).apply(func, raw=False)
    return out.add_prefix(pre)

skew7  = rolling_apply(ret1, 7,  skew,     "skew7_")
skew14 = rolling_apply(ret1, 14, skew,     "skew14_")
kurt7  = rolling_apply(ret1, 7,  kurtosis, "kurt7_")
kurt14 = rolling_apply(ret1, 14, kurtosis, "kurt14_")

# %%
# volume features
df_vol = df[df["volume"] > 0].copy().sort_values(["symbol","time"])
df_vol["log_volume"] = np.log(df_vol["volume"])
df_vol["log_vol_return"] = df_vol.groupby("symbol")["log_volume"].diff()

vol_mat = df_vol.pivot(index="time", columns="symbol", values="log_vol_return")
vol_mat = vol_mat[top20_symbols].reindex(prices.index).add_prefix("volret_")

vol_raw = df_vol.pivot(index="time", columns="symbol", values="volume")
vol_raw = vol_raw[top20_symbols].reindex(prices.index)

vol_ma7  = vol_raw.rolling(7).mean().add_prefix("volma7_")
vol_ma14 = vol_raw.rolling(14).mean().add_prefix("volma14_")
vol_std7 = vol_raw.rolling(7).std().add_prefix("volstd7_")

# order matrix (nếu có)
order_mat = None
if "order" in df.columns:
    order_mat = df.pivot(index="time", columns="symbol", values="order")
    order_mat = order_mat[top20_symbols].reindex(prices.index).add_prefix("ord_")

# usdreturn (nếu có)
usd_series = None
if "usdreturn" in df.columns:
    usd_series = df.groupby("time")["usdreturn"].first().reindex(prices.index).rename("usdreturn")

# %% [markdown]
# ## Load causal features (PMIME + CGCI), merge, broadcast by day

# %%
pmime = pd.read_csv(PATH_PMIME)
cgci  = pd.read_csv(PATH_CGCI)

pmime["symbol"] = pmime["symbol"].astype(str).str.upper()
cgci["symbol"]  = cgci["symbol"].astype(str).str.upper()

# chỉ lấy các mã thuộc top20
pmime = pmime[pmime["symbol"].isin(top20_symbols)].copy()
cgci  = cgci[cgci["symbol"].isin(top20_symbols)].copy()

# merge 2 bảng theo symbol
causal = pd.merge(pmime, cgci, on="symbol", how="outer")

# fill missing (phòng trường hợp thiếu mã ở pmime)
for c in causal.columns:
    if c != "symbol":
        causal[c] = pd.to_numeric(causal[c], errors="coerce")
causal = causal.fillna(0)

print("✅ Causal table (symbol-level):", causal.shape)
print(causal.head())

# broadcast to daily matrix
causal_index = prices.index

causal_wide_list = []
feat_cols = [c for c in causal.columns if c != "symbol"]

for f in feat_cols:
    s = causal.set_index("symbol")[f].reindex(top20_symbols)
    wide = pd.DataFrame(
        np.tile(s.values, (len(causal_index), 1)),
        index=causal_index,
        columns=[f"{f}_{sym}" for sym in top20_symbols]
    )
    causal_wide_list.append(wide)

causal_wide = pd.concat(causal_wide_list, axis=1)
# shift 1 ngày để “an toàn” chống leak theo thời gian
causal_wide = causal_wide.shift(1)

print("✅ causal_wide:", causal_wide.shape)
# Out:
# ✅ Causal table (symbol-level): (20, 14)
#   symbol  pmime_out  pmime_in  pmime_net  deg_out  deg_in  deg_net  \
# 0    ACB   1.011410  2.144142  -1.132732        5      12       -7
# 1    CTG   1.393172  1.613614  -0.220442        6      10       -4
# 2    EIB   2.080983  1.668045   0.412938       11      11        0
# 3    HDB   3.012691  2.065742   0.946948       11       9        2
# 4    HPG   2.560431  1.461456   1.098975       13       9        4
#
#    betweenness  eigenvector  pagerank  community_id  cgci_outdeg  cgci_indeg  \
# 0    11.976526     0.046933  0.059229             1            1           3
# 1     7.169383     0.049304  0.043215             1            4           2
# 2     9.437302     0.049319  0.048864             1            3           1
# 3    17.552595     0.044465  0.040089             1            1           0
# 4    29.993407     0.059180  0.049602             1            0           4
#
#    cgci_netdeg
# 0           -2
# 1            2
# 2            2
# 3            1
# 4           -4
# ✅ causal_wide: (946, 260)

# %% [markdown]
# ## Build dataset_full (features + target)

# %%
parts = [
    ret1,
    mom5, mom10, mom20,
    ma7, ma14, ma21,
    vol7, vol14, vol21,
    vol_ratio,
    skew7, skew14,
    kurt7, kurt14,
    vol_mat, vol_ma7, vol_ma14, vol_std7,
    order_mat,
    usd_series,
    ret5
]

print("✅ parts defined:", len(parts))
# Out:
# ✅ parts defined: 22

# %%
# 5.1) Concat tất cả parts
dataset_full = pd.concat(parts, axis=1)

print("Before cleaning:", dataset_full.shape)
print("Index range:", dataset_full.index.min(), "->", dataset_full.index.max())

# 5.2) Chỉ drop theo TARGET (y5_) vì nếu không có target thì không train được
ycols = [c for c in dataset_full.columns if c.startswith("y5_")]
if len(ycols) == 0:
    raise ValueError("Không thấy cột target y5_. Kiểm tra ret5 tạo đúng chưa.")

dataset_full = dataset_full.dropna(subset=ycols).copy()

print("After dropna(target):", dataset_full.shape)
print("Index range:", dataset_full.index.min(), "->", dataset_full.index.max())

# 5.3) Fill NA cho FEATURES (khuyến nghị cho tree models)
dataset_full = dataset_full.sort_index()
dataset_full = dataset_full.fillna(method="ffill").fillna(0)

# 5.4) Sanity checks
assert len(dataset_full) > 0, "❌ dataset_full vẫn rỗng sau khi xử lý!"
assert dataset_full.index.is_monotonic_increasing, "❌ Index thời gian không tăng dần!"
assert dataset_full.index.is_unique, "❌ Index bị trùng!"

# check đủ target cho top20
missing_targets = [f"y5_{sym}" for sym in top20_symbols if f"y5_{sym}" not in dataset_full.columns]
if missing_targets:
    raise ValueError(f"❌ Thiếu target cho các mã: {missing_targets}")

# check causal cols có tồn tại
causal_cols = [c for c in dataset_full.columns if c.startswith("cgci_") or c.startswith("pmime_")]
print("✅ #causal cols:", len(causal_cols))
print("✅ dataset_full:", dataset_full.shape)
print("✅ Date range:", dataset_full.index.min(), "->", dataset_full.index.max())
# Out:
# Before cleaning: (946, 441)
# Index range: 2021-03-24 00:00:00 -> 2024-12-31 00:00:00
# After dropna(target): (935, 441)
# Index range: 2021-03-24 00:00:00 -> 2024-12-24 00:00:00
# ✅ #causal cols: 0
# ✅ dataset_full: (935, 441)
# ✅ Date range: 2021-03-24 00:00:00 -> 2024-12-24 00:00:00
# C:\Users\nhokk\AppData\Local\Temp\ipykernel_14640\4243465280.py:25: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset_full = dataset_full.fillna(method="ffill").fillna(0)

# %% [markdown]
# ## Build binary target y5cls_ (classification) - y5cls = 1 if forward 5d log return > 0 else 0

# %%
# target log-return 5 ngày
ycols = [c for c in dataset_full.columns if c.startswith("y5_")]

y_bin = (dataset_full[ycols] > 0).astype(int)
y_bin.columns = [c.replace("y5_", "y5cls_") for c in y_bin.columns]

# feature matrix
X = dataset_full.drop(columns=ycols)
y = y_bin.copy()

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (935, 421)
# y shape: (935, 20)

# %% [markdown]
# ## Model factories (ET vs RF)

# %%
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier

def make_et():
    return ExtraTreesClassifier(
        n_estimators=300,
        max_depth=None,
        random_state=42,
        n_jobs=-1
    )

def make_rf():
    return RandomForestClassifier(
        n_estimators=300,
        max_depth=None,
        random_state=42,
        n_jobs=-1
    )

print("✅ Model factories ready")
# Out:
# ✅ Model factories ready

# %%
# OOS prediction for model comparison
def oos_predict(model_maker, X, y, min_train=252):
    P_list = []
    dates = []

    for i in range(min_train, len(X)):
        X_tr = X.iloc[:i]
        y_tr = y.iloc[:i]
        X_te = X.iloc[[i]]

        model = model_maker()
        model.fit(X_tr, y_tr)

        proba = model.predict_proba(X_te)
        p1 = [p[0,1] for p in proba]

        P_list.append(p1)
        dates.append(X.index[i])

    return pd.DataFrame(
        P_list,
        index=dates,
        columns=[c.replace("y5cls_", "") for c in y.columns]
    )

# %%
P_ET = oos_predict(make_et, X, y)
P_RF = oos_predict(make_rf, X, y)

print("ET OOS shape:", P_ET.shape)
print("RF OOS shape:", P_RF.shape)
# Out:
# ET OOS shape: (683, 20)
# RF OOS shape: (683, 20)

# %%
# target thực tế
y_true = y.loc[P_ET.index]
y_true.columns = [c.replace("y5cls_", "") for c in y_true.columns]

# Brier loss (trung bình cross-section mỗi ngày)
loss_ET = ((P_ET - y_true) ** 2).mean(axis=1)
loss_RF = ((P_RF - y_true) ** 2).mean(axis=1)

print("Mean Brier loss ET:", loss_ET.mean())
print("Mean Brier loss RF:", loss_RF.mean())
# Out:
# Mean Brier loss ET: 0.16887161542215715
# Mean Brier loss RF: 0.1853027981129006

# %% [markdown]
# ## Model selection: Brier loss + DM-style t-test

# %%
from scipy import stats

d = loss_RF - loss_ET   # >0 ⇒ ET tốt hơn
t_stat, p_value = stats.ttest_1samp(d, 0)

print("DM t-stat :", t_stat)
print("p-value   :", p_value)
# Out:
# DM t-stat : 18.3907509189461
# p-value   : 1.2002741940867295e-61

# %% [markdown]
# ## Build P_up_oos using ExtraTrees (for charts/leader backtest)

# %%
from sklearn.ensemble import ExtraTreesClassifier

P_up_oos = []   # out-of-sample probabilities
dates_oos = []

min_train = 252   # ~1 năm giao dịch

for i in range(min_train, len(X)):
    X_train = X.iloc[:i]
    y_train = y.iloc[:i]

    X_test  = X.iloc[[i]]

    model = ExtraTreesClassifier(
        n_estimators=300,
        max_depth=None,
        random_state=42,
        n_jobs=-1
    )
    model.fit(X_train, y_train)

    proba = model.predict_proba(X_test)
    p1 = [p[0,1] for p in proba]

    P_up_oos.append(p1)
    dates_oos.append(X.index[i])

P_up_oos = pd.DataFrame(
    P_up_oos,
    index=dates_oos,
    columns=[c.replace("y5cls_", "") for c in y.columns]
)

print("✅ P_up_oos shape:", P_up_oos.shape)
P_up_oos.head()
# Out:
# ✅ P_up_oos shape: (683, 20)
#                  HPG       STB       SHB       SSI       VPB       NVL  \
# 2022-04-05  0.406667  0.256667  0.153333  0.356667  0.363333  0.370000
# 2022-04-06  0.320000  0.120000  0.173333  0.253333  0.463333  0.296667
# 2022-04-07  0.210000  0.113333  0.140000  0.206667  0.346667  0.226667
# 2022-04-08  0.340000  0.313333  0.270000  0.316667  0.420000  0.346667
# 2022-04-12  0.406667  0.333333  0.290000  0.333333  0.400000  0.340000
#
#                  MBB       TCB       TCH       CTG       LPB       PDR  \
# 2022-04-05  0.283333  0.183333  0.216667  0.206667  0.296667  0.316667
# 2022-04-06  0.160000  0.120000  0.196667  0.086667  0.183333  0.243333
# 2022-04-07  0.150000  0.133333  0.163333  0.096667  0.130000  0.176667
# 2022-04-08  0.296667  0.273333  0.250000  0.220000  0.276667  0.343333
# 2022-04-12  0.326667  0.280000  0.263333  0.246667  0.296667  0.323333
#
#                  TPB       ACB       VHM       VRE       HDB       MWG  \
# 2022-04-05  0.346667  0.330000  0.143333  0.190000  0.246667  0.333333
# 2022-04-06  0.230000  0.453333  0.133333  0.156667  0.136667  0.520000
# 2022-04-07  0.210000  0.613333  0.113333  0.130000  0.116667  0.660000
# 2022-04-08  0.360000  0.396667  0.216667  0.246667  0.283333  0.620000
# 2022-04-12  0.440000  0.373333  0.270000  0.300000  0.310000  0.730000
#
#                  EIB       VIB
# 2022-04-05  0.166667  0.253333
# 2022-04-06  0.136667  0.173333
# 2022-04-07  0.126667  0.160000
# 2022-04-08  0.243333  0.310000
# 2022-04-12  0.246667  0.340000

# %% [markdown]
# ## Realized 5d simple return (for leader contribution scoring)

# %%
# ycols = target log-return 5 ngày
ycols = [c for c in dataset_full.columns if c.startswith("y5_")]

ret5_simple = np.exp(dataset_full[ycols]) - 1
ret5_simple.columns = [c.replace("y5_", "") for c in ret5_simple.columns]

print("✅ ret5_simple:", ret5_simple.shape, ret5_simple.index.min(), "->", ret5_simple.index.max())
# Out:
# ✅ ret5_simple: (935, 20) 2021-03-24 00:00:00 -> 2024-12-24 00:00:00

# %% [markdown]
# ## OOS Leaders 2021–2024

# %%
leader_results = {}

for yr in [2021, 2022, 2023, 2024]:
    idx = P_up_oos.index[P_up_oos.index.year == yr]   

    P = P_up_oos.loc[idx]
    R = ret5_simple.loc[idx]                          

    picks = P.idxmax(axis=1)

    contrib = pd.Series(0.0, index=P.columns)
    for t, sym in picks.items():
        contrib[sym] += R.loc[t, sym]

    leader = contrib.sort_values(ascending=False)
    leader_results[yr] = leader

    print(f"\n🏆 PREDICTED LEADER {yr} (OOS)")
    print(leader.head(5))
# Out:
# 🏆 PREDICTED LEADER 2021 (OOS)
# HPG    0.0
# STB    0.0
# SHB    0.0
# SSI    0.0
# VPB    0.0
# dtype: float64
#
# 🏆 PREDICTED LEADER 2022 (OOS)
# LPB    1.481676
# SSI    1.125088
# EIB    1.064422
# MWG    0.884952
# HDB    0.467236
# dtype: float64
#
# 🏆 PREDICTED LEADER 2023 (OOS)
# LPB    1.621308
# HPG    1.142733
# SSI    0.921695
# HDB    0.557751
# NVL    0.460007
# dtype: float64
#
# 🏆 PREDICTED LEADER 2024 (OOS)
# LPB    2.128450
# MBB    1.419019
# TCH    0.725072
# TCB    0.452047
# HDB    0.408584
# dtype: float64

# %% [markdown]
# # Train final model on FULL sample (2021–2024)

# %%
from sklearn.ensemble import ExtraTreesClassifier

final_model = ExtraTreesClassifier(
    n_estimators=600,
    max_depth=None,
    random_state=42,
    n_jobs=-1
)

final_model.fit(X, y)
print("✅ Final ExtraTrees model trained (2021–2024)")
# Out:
# ✅ Final ExtraTrees model trained (2021–2024)

# %% [markdown]
# # Robust ML forecast for 2025

# %%
K = 20  # số ngày cuối 2024
snapshots_2025 = X.index[-K:]

scores_2025 = pd.Series(0.0, index=[c.replace("y5cls_", "") for c in y.columns])

for d in snapshots_2025:
    X_d = X.loc[[d]]
    proba_d = final_model.predict_proba(X_d)

    P_d = pd.Series(
        [p[0,1] for p in proba_d],
        index=scores_2025.index
    )

    scores_2025 += P_d

# Trung bình xác suất
scores_2025 = (scores_2025 / K).sort_values(ascending=False)

print("🔮 ML FORECAST — LEADER SIGNALS 2025 (ROBUST)")
print(scores_2025.head(10))

print("\n🏆 PREDICTED LEADER 2025:", scores_2025.index[0])
# Out:
# 🔮 ML FORECAST — LEADER SIGNALS 2025 (ROBUST)
# STB    0.85
# LPB    0.80
# HDB    0.80
# TCB    0.75
# SSI    0.70
# EIB    0.65
# CTG    0.60
# VIB    0.55
# ACB    0.50
# MWG    0.50
# dtype: float64
#
# 🏆 PREDICTED LEADER 2025: STB

# %% [markdown]
# # Charts with Probability

# %%
import matplotlib.pyplot as plt
import pandas as pd

def plot_price_with_signal(sym, year=2024, hi=0.6, lo=0.4):
    # Chỉ lấy 1 năm cho dễ nhìn
    idx = P_up_oos.index[P_up_oos.index.year == year]

    price = prices.loc[idx, sym]
    p_up  = P_up_oos.loc[idx, sym]

    plt.figure(figsize=(10, 4))
    plt.plot(price.index, price.values, label=f"{sym} Close Price")

    y_min, y_max = price.min(), price.max()

    # Tô nền theo tín hiệu ML
    plt.fill_between(
        price.index, y_min, y_max,
        where=(p_up > hi),
        alpha=0.15,
        label="ML signal: P(up) > 0.6"
    )

    plt.fill_between(
        price.index, y_min, y_max,
        where=(p_up < lo),
        alpha=0.15,
        label="ML signal: P(up) < 0.4"
    )

    plt.title(f"{sym} — Real Price with ML Signal ({year}, OOS)")
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
plot_price_with_signal("LPB", year=2024)
plot_price_with_signal("STB", year=2024)

# %% [markdown]
# # Predict 2026 (Volume)

# %%
K_2026 = 60   # số ngày dùng để đo độ ổn định

snapshot_dates = X.index[-K_2026:]

print("Using snapshots from:",
      snapshot_dates.min(), "→", snapshot_dates.max())
# Out:
# Using snapshots from: 2024-10-02 00:00:00 → 2024-12-24 00:00:00

# %%
symbols = [c.replace("y5cls_", "") for c in y.columns]

P_sum = pd.Series(0.0, index=symbols)
P_sq  = pd.Series(0.0, index=symbols)

# %%
for d in snapshot_dates:
    X_d = X.loc[[d]]  # 1 snapshot

    proba = final_model.predict_proba(X_d)

    # lấy xác suất P(up) cho từng mã
    P_d = pd.Series(
        [p[0, 1] for p in proba],
        index=symbols
    )

    P_sum += P_d
    P_sq  += P_d ** 2

# %%
avg_P_up = P_sum / K_2026
std_P_up = np.sqrt(P_sq / K_2026 - avg_P_up**2)

# %%
leader_2026 = pd.DataFrame({
    "avg_P_up": avg_P_up,
    "std_P_up": std_P_up
}).sort_values(
    ["avg_P_up", "std_P_up"],
    ascending=[False, True]
)

print("🔮 ML STABILITY FORECAST — 2026")
print(leader_2026.head(10))

print("\n🏆 PREDICTED LEADER 2026:", leader_2026.index[0])
# Out:
# 🔮 ML STABILITY FORECAST — 2026
#      avg_P_up  std_P_up
# STB  0.666667  0.471405
# LPB  0.600000  0.489898
# CTG  0.533333  0.498888
# HPG  0.500000  0.500000
# TCB  0.483333  0.499722
# HDB  0.483333  0.499722
# VPB  0.450000  0.497494
# VHM  0.450000  0.497494
# EIB  0.450000  0.497494
# VIB  0.450000  0.497494
#
# 🏆 PREDICTED LEADER 2026: STB

# %%
# !pip install adjustText
# Out:
# Requirement already satisfied: adjustText in d:\anaconda\envs\causalvn\lib\site-packages (1.3.0)
# Requirement already satisfied: numpy in d:\anaconda\envs\causalvn\lib\site-packages (from adjustText) (2.2.5)
# Requirement already satisfied: matplotlib in d:\anaconda\envs\causalvn\lib\site-packages (from adjustText) (3.10.6)
# Requirement already satisfied: scipy in d:\anaconda\envs\causalvn\lib\site-packages (from adjustText) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\envs\causalvn\lib\site-packages (from matplotlib->adjustText) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\envs\causalvn\lib\site-packages (from matplotlib->adjustText) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\envs\causalvn\lib\site-packages (from matplotlib->adjustText) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\envs\causalvn\lib\site-packages (from matplotlib->adjustText) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\envs\causalvn\lib\site-packages (from matplotlib->adjustText) (25.0)
# Requirement already satisfied: pillow>=8 in d:\anaconda\envs\causalvn\lib\site-packages (from matplotlib->adjustText) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\envs\causalvn\lib\site-packages (from matplotlib->adjustText) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\envs\causalvn\lib\site-packages (from matplotlib->adjustText) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\causalvn\lib\site-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.17.0)

# %%
import matplotlib.pyplot as plt

df = leader_2026.copy()

plt.figure(figsize=(7, 5))

# Scatter toàn bộ cổ phiếu
plt.scatter(
    df["avg_P_up"],
    df["std_P_up"],
    alpha=0.7
)

# Annotate từng mã
for sym, row in df.iterrows():
    plt.text(
        row["avg_P_up"] + 0.002,
        row["std_P_up"] + 0.002,
        sym,
        fontsize=9
    )

# Highlight STB
plt.scatter(
    df.loc["STB", "avg_P_up"],
    df.loc["STB", "std_P_up"],
    s=150,
    edgecolors="black",
    linewidths=1.5
)
plt.text(
    df.loc["STB", "avg_P_up"],
    df.loc["STB", "std_P_up"] - 0.015,
    "STB (Leader 2026)",
    fontsize=11,
    fontweight="bold",
    ha="center"
)

plt.xlabel("Average predicted P(up)")
plt.ylabel("Std of predicted P(up)")
plt.title("Stability-based ML Forecast — Leader 2026")

plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

df = leader_2026.copy()

leader = "STB"
top_k = 5
top_syms = df.head(top_k).index.tolist()

plt.figure(figsize=(7, 5))

# Others
others = df.index.difference(top_syms)
plt.scatter(
    df.loc[others, "avg_P_up"],
    df.loc[others, "std_P_up"],
    alpha=0.4,
    label="Other stocks"
)

# Top contenders (excluding leader)
top_others = [s for s in top_syms if s != leader]
plt.scatter(
    df.loc[top_others, "avg_P_up"],
    df.loc[top_others, "std_P_up"],
    s=90,
    alpha=0.8,
    label="Top contenders"
)

# Leader
plt.scatter(
    df.loc[leader, "avg_P_up"],
    df.loc[leader, "std_P_up"],
    s=180,
    marker="*",
    edgecolors="black",
    linewidths=1.5,
    label="Leader 2026 (STB)"
)

plt.xlabel("Average predicted P(up)")
plt.ylabel("Std of predicted P(up)")
plt.title("Stability-based ML Forecast — Leader 2026")

plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # VOLATILITY

# %% [markdown]
# ## Imports & Paths

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis

PATH_DATA  = r"C:/Users/nhokk/Downloads/FINAL DATASET.xlsx"
PATH_PMIME = r"C:/Users/nhokk/Downloads/PMIME_features_for_python.csv"
PATH_CGCI  = r"C:/Users/nhokk/Downloads/cgci_node_scores_top20volatility_2021_2024.csv"

# %% [markdown]
# ## SELECT 20 STOCKS VOLATILITY

# %%
TOP_N_STOCKS = 20

df_raw = pd.read_excel(PATH_DATA)
df = df_raw.copy()
df.columns = [c.lower() for c in df.columns]

df["time"] = pd.to_datetime(df["time"])
df["symbol"] = df["symbol"].astype(str).str.upper()

# thời gian 2021-03-24 -> 2024-12-31
df = df[(df["time"] >= "2021-03-24") & (df["time"] < "2025-01-01")].copy()

# loại index và ROS
exclude = {"VNINDEX","VN-INDEX","VN30","VN-30","VN30INDEX","ROS"}
df = df[~df["symbol"].isin(exclude)].copy()

# remove duplicates key
df = df.drop_duplicates(subset=["time","symbol"]).copy()

# top 20 theo total volume
prices_all = df.pivot(index="time", columns="symbol", values="close").sort_index()
log_p_all  = np.log(prices_all)
logret_all = log_p_all.diff()

vol_stats = logret_all.std(skipna=True).sort_values(ascending=False)

top_symbols = vol_stats.head(TOP_N_STOCKS).index.tolist()
df = df[df["symbol"].isin(top_symbols)].copy()

print("✅ Top symbols (volatility):", top_symbols)
print("✅ Base df:", df.shape)
# Out:
# ✅ Top symbols (volatility): ['TCH', 'GVR', 'SSI', 'DGC', 'PDR', 'NVL', 'EIB', 'LPB', 'STB', 'SBT', 'SHB', 'VRE', 'MSN', 'MWG', 'KDH', 'HPG', 'BCM', 'TPB', 'REE', 'VIB']
# ✅ Base df: (18917, 9)

# %% [markdown]
# ## Technical features

# %%
prices = df.pivot(index="time", columns="symbol", values="close").sort_index()
prices = prices[top_symbols].copy()
log_p = np.log(prices)

ret1 = log_p.diff().add_prefix("ret1_")
ret5 = (log_p.shift(-5) - log_p).add_prefix("y5_")   # TARGET (forward 5d log-return)

mom5  = log_p.diff(5).add_prefix("mom5_")
mom10 = log_p.diff(10).add_prefix("mom10_")
mom20 = log_p.diff(20).add_prefix("mom20_")

ma7  = ret1.rolling(7).mean().add_prefix("ma7_")
ma14 = ret1.rolling(14).mean().add_prefix("ma14_")
ma21 = ret1.rolling(21).mean().add_prefix("ma21_")

vol7  = ret1.rolling(7).std().add_prefix("vol7_")
vol14 = ret1.rolling(14).std().add_prefix("vol14_")
vol21 = ret1.rolling(21).std().add_prefix("vol21_")

vol_ratio = (vol7 / (vol21 + 1e-8))
vol_ratio.columns = [c.replace("vol7_", "volratio_") for c in vol_ratio.columns]

def rolling_apply(df_in, w, func, pre):
    out = pd.DataFrame(index=df_in.index, columns=df_in.columns, dtype="float64")
    for c in df_in.columns:
        out[c] = df_in[c].rolling(w).apply(func, raw=False)
    return out.add_prefix(pre)

skew7  = rolling_apply(ret1, 7,  skew,     "skew7_")
skew14 = rolling_apply(ret1, 14, skew,     "skew14_")
kurt7  = rolling_apply(ret1, 7,  kurtosis, "kurt7_")
kurt14 = rolling_apply(ret1, 14, kurtosis, "kurt14_")

# %%
# volume features
df_vol = df[df["volume"] > 0].copy().sort_values(["symbol","time"])
df_vol["log_volume"] = np.log(df_vol["volume"])
df_vol["log_vol_return"] = df_vol.groupby("symbol")["log_volume"].diff()

vol_mat = df_vol.pivot(index="time", columns="symbol", values="log_vol_return")
vol_mat = vol_mat[top_symbols].reindex(prices.index).add_prefix("volret_")

vol_raw = df_vol.pivot(index="time", columns="symbol", values="volume")
vol_raw = vol_raw[top_symbols].reindex(prices.index)

vol_ma7  = vol_raw.rolling(7).mean().add_prefix("volma7_")
vol_ma14 = vol_raw.rolling(14).mean().add_prefix("volma14_")
vol_std7 = vol_raw.rolling(7).std().add_prefix("volstd7_")

# order matrix (nếu có)
order_mat = None
if "order" in df.columns:
    order_mat = df.pivot(index="time", columns="symbol", values="order")
    order_mat = order_mat[top_symbols].reindex(prices.index).add_prefix("ord_")

# usdreturn (nếu có)
usd_series = None
if "usdreturn" in df.columns:
    usd_series = df.groupby("time")["usdreturn"].first().reindex(prices.index).rename("usdreturn")

# %% [markdown]
# ## Load causal features (PMIME + CGCI), merge, broadcast by day

# %%
pmime = pd.read_csv(PATH_PMIME)
cgci  = pd.read_csv(PATH_CGCI)

pmime["symbol"] = pmime["symbol"].astype(str).str.upper()
cgci["symbol"]  = cgci["symbol"].astype(str).str.upper()

# chỉ lấy các mã thuộc top20
pmime = pmime[pmime["symbol"].isin(top_symbols)].copy()
cgci  = cgci[cgci["symbol"].isin(top_symbols)].copy()

# merge 2 bảng theo symbol
causal = pd.merge(pmime, cgci, on="symbol", how="outer")

# fill missing (phòng trường hợp thiếu mã ở pmime)
for c in causal.columns:
    if c != "symbol":
        causal[c] = pd.to_numeric(causal[c], errors="coerce")
causal = causal.fillna(0)

print("✅ Causal table (symbol-level):", causal.shape)
print(causal.head())

# broadcast causal features ra theo ngày: tạo DataFrame index=time, columns=feature_symbol
causal_index = prices.index

causal_wide_list = []
feat_cols = [c for c in causal.columns if c != "symbol"]

for f in feat_cols:
    s = causal.set_index("symbol")[f].reindex(top_symbols)
    wide = pd.DataFrame(
        np.tile(s.values, (len(causal_index), 1)),
        index=causal_index,
        columns=[f"{f}_{sym}" for sym in top_symbols]
    )
    causal_wide_list.append(wide)

causal_wide = pd.concat(causal_wide_list, axis=1)

# (khuyến nghị) shift 1 ngày để “an toàn” chống leak theo thời gian
# nếu bạn muốn giữ nguyên thì comment dòng dưới
causal_wide = causal_wide.shift(1)

print("✅ causal_wide:", causal_wide.shape)
# Out:
# ✅ Causal table (symbol-level): (19, 14)
#   symbol  pmime_out  pmime_in  pmime_net  deg_out  deg_in  deg_net  \
# 0    BCM   0.000000  0.000000   0.000000      0.0     0.0      0.0
# 1    DGC   0.000000  0.000000   0.000000      0.0     0.0      0.0
# 2    EIB   2.080983  1.668045   0.412938     11.0    11.0      0.0
# 3    GVR   0.000000  0.000000   0.000000      0.0     0.0      0.0
# 4    HPG   2.560431  1.461456   1.098975     13.0     9.0      4.0
#
#    betweenness  eigenvector  pagerank  community_id  out_degree  in_degree  \
# 0     0.000000     0.000000  0.000000           0.0         0.0        0.0
# 1     0.000000     0.000000  0.000000           0.0         1.0        0.0
# 2     9.437302     0.049319  0.048864           1.0         4.0        0.0
# 3     0.000000     0.000000  0.000000           0.0         1.0        1.0
# 4    29.993407     0.059180  0.049602           1.0         3.0        4.0
#
#    net_degree
# 0         0.0
# 1         1.0
# 2         4.0
# 3         0.0
# 4        -1.0
# ✅ causal_wide: (946, 260)

# %% [markdown]
# ## Build dataset_full (features + target)

# %%
parts = [
    ret1,
    mom5, mom10, mom20,
    ma7, ma14, ma21,
    vol7, vol14, vol21,
    vol_ratio,
    skew7, skew14,
    kurt7, kurt14,
    vol_mat, vol_ma7, vol_ma14, vol_std7,
    order_mat,
    usd_series,
    causal_wide,   # ✅ THÊM DÒNG NÀY
    ret5
]

print("✅ parts defined:", len(parts))
# Out:
# ✅ parts defined: 23

# %%
# 5.1) Concat tất cả parts (KHÔNG dropna vội)
dataset_full = pd.concat(parts, axis=1)

print("Before cleaning:", dataset_full.shape)
print("Index range:", dataset_full.index.min(), "->", dataset_full.index.max())

# 5.2) Chỉ drop theo TARGET (y5_) vì nếu không có target thì không train được
ycols = [c for c in dataset_full.columns if c.startswith("y5_")]
if len(ycols) == 0:
    raise ValueError("Không thấy cột target y5_. Kiểm tra ret5 tạo đúng chưa.")

dataset_full = dataset_full.dropna(subset=ycols).copy()

print("After dropna(target):", dataset_full.shape)
print("Index range:", dataset_full.index.min(), "->", dataset_full.index.max())

# 5.3) Fill NA cho FEATURES (khuyến nghị cho tree models)
# Nếu bạn muốn nghiêm ngặt hơn: có thể ffill theo thời gian trước rồi fill 0
dataset_full = dataset_full.sort_index()
dataset_full = dataset_full.fillna(method="ffill").fillna(0)

# 5.4) Sanity checks
assert len(dataset_full) > 0, "❌ dataset_full vẫn rỗng sau khi xử lý!"
assert dataset_full.index.is_monotonic_increasing, "❌ Index thời gian không tăng dần!"
assert dataset_full.index.is_unique, "❌ Index bị trùng!"

# check đủ target cho top20
missing_targets = [f"y5_{sym}" for sym in top_symbols if f"y5_{sym}" not in dataset_full.columns]
if missing_targets:
    raise ValueError(f"❌ Thiếu target cho các mã: {missing_targets}")

# check causal cols có tồn tại
causal_cols = [c for c in dataset_full.columns if c.startswith("cgci_") or c.startswith("pmime_")]
print("✅ #causal cols:", len(causal_cols))
print("✅ dataset_full:", dataset_full.shape)
print("✅ Date range:", dataset_full.index.min(), "->", dataset_full.index.max())
# Out:
# Before cleaning: (946, 701)
# Index range: 2021-03-24 00:00:00 -> 2024-12-31 00:00:00
# After dropna(target): (935, 701)
# Index range: 2021-03-24 00:00:00 -> 2024-12-24 00:00:00
# ✅ #causal cols: 60
# ✅ dataset_full: (935, 701)
# ✅ Date range: 2021-03-24 00:00:00 -> 2024-12-24 00:00:00
# C:\Users\nhokk\AppData\Local\Temp\ipykernel_12048\3524985330.py:20: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset_full = dataset_full.fillna(method="ffill").fillna(0)

# %% [markdown]
# ## Build binary target y5cls_ (classification) - y5cls = 1 if forward 5d log return > 0 else 0

# %%
# target log-return 5 ngày
ycols = [c for c in dataset_full.columns if c.startswith("y5_")]

y_bin = (dataset_full[ycols] > 0).astype(int)
y_bin.columns = [c.replace("y5_", "y5cls_") for c in y_bin.columns]

# feature matrix
X = dataset_full.drop(columns=ycols)
y = y_bin.copy()

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (935, 681)
# y shape: (935, 20)

# %% [markdown]
# ## Model factories (ET vs RF)

# %%
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier

def make_et():
    return ExtraTreesClassifier(
        n_estimators=300,
        max_depth=None,
        random_state=42,
        n_jobs=-1
    )

def make_rf():
    return RandomForestClassifier(
        n_estimators=300,
        max_depth=None,
        random_state=42,
        n_jobs=-1
    )

print("✅ Model factories ready")
# Out:
# ✅ Model factories ready

# %%
# OOS prediction for model comparison
def oos_predict(model_maker, X, y, min_train=252):
    P_list = []
    dates = []

    for i in range(min_train, len(X)):
        X_tr = X.iloc[:i]
        y_tr = y.iloc[:i]
        X_te = X.iloc[[i]]

        model = model_maker()
        model.fit(X_tr, y_tr)

        proba = model.predict_proba(X_te)
        p1 = [p[0,1] for p in proba]

        P_list.append(p1)
        dates.append(X.index[i])

    return pd.DataFrame(
        P_list,
        index=dates,
        columns=[c.replace("y5cls_", "") for c in y.columns]
    )

# %%
P_ET = oos_predict(make_et, X, y)
P_RF = oos_predict(make_rf, X, y)

print("ET OOS shape:", P_ET.shape)
print("RF OOS shape:", P_RF.shape)
# Out:
# ET OOS shape: (683, 20)
# RF OOS shape: (683, 20)

# %%
# target thực tế
y_true = y.loc[P_ET.index]
y_true.columns = [c.replace("y5cls_", "") for c in y_true.columns]

# Brier loss (trung bình cross-section mỗi ngày)
loss_ET = ((P_ET - y_true) ** 2).mean(axis=1)
loss_RF = ((P_RF - y_true) ** 2).mean(axis=1)

print("Mean Brier loss ET:", loss_ET.mean())
print("Mean Brier loss RF:", loss_RF.mean())
# Out:
# Mean Brier loss ET: 0.17057107694810478
# Mean Brier loss RF: 0.18685591345371724

# %% [markdown]
# ## Model selection: Brier loss + DM-style t-test

# %%
from scipy import stats

d = loss_RF - loss_ET   # >0 ⇒ ET tốt hơn
t_stat, p_value = stats.ttest_1samp(d, 0)

print("DM t-stat :", t_stat)
print("p-value   :", p_value)
# Out:
# DM t-stat : 20.371739745045495
# p-value   : 2.0132124148572184e-72

# %% [markdown]
# ## Build P_up_oos using ExtraTrees (for charts/leader backtest)

# %%
from sklearn.ensemble import ExtraTreesClassifier

P_up_oos = []   # out-of-sample probabilities
dates_oos = []

min_train = 252   # ~1 năm giao dịch

for i in range(min_train, len(X)):
    X_train = X.iloc[:i]
    y_train = y.iloc[:i]

    X_test  = X.iloc[[i]]

    model = ExtraTreesClassifier(
        n_estimators=300,
        max_depth=None,
        random_state=42,
        n_jobs=-1
    )
    model.fit(X_train, y_train)

    proba = model.predict_proba(X_test)
    p1 = [p[0,1] for p in proba]

    P_up_oos.append(p1)
    dates_oos.append(X.index[i])

P_up_oos = pd.DataFrame(
    P_up_oos,
    index=dates_oos,
    columns=[c.replace("y5cls_", "") for c in y.columns]
)

print("✅ P_up_oos shape:", P_up_oos.shape)
P_up_oos.head()
# Out:
# ✅ P_up_oos shape: (683, 20)
#                  TCH       GVR       SSI       DGC       PDR       NVL  \
# 2022-04-05  0.176667  0.383333  0.366667  0.333333  0.290000  0.336667
# 2022-04-06  0.213333  0.313333  0.286667  0.660000  0.280000  0.280000
# 2022-04-07  0.200000  0.210000  0.250000  0.733333  0.243333  0.223333
# 2022-04-08  0.246667  0.336667  0.313333  0.740000  0.276667  0.280000
# 2022-04-12  0.196667  0.700000  0.320000  0.750000  0.313333  0.323333
#
#                  EIB       LPB       STB       SBT       SHB       VRE  \
# 2022-04-05  0.206667  0.333333  0.246667  0.223333  0.236667  0.206667
# 2022-04-06  0.186667  0.230000  0.203333  0.246667  0.186667  0.206667
# 2022-04-07  0.196667  0.206667  0.183333  0.220000  0.176667  0.183333
# 2022-04-08  0.250000  0.276667  0.296667  0.293333  0.256667  0.290000
# 2022-04-12  0.220000  0.260000  0.260000  0.266667  0.250000  0.213333
#
#                  MSN       MWG       KDH       HPG       BCM       TPB  \
# 2022-04-05  0.770000  0.310000  0.250000  0.383333  0.646667  0.353333
# 2022-04-06  0.783333  0.613333  0.256667  0.330000  0.640000  0.326667
# 2022-04-07  0.556667  0.660000  0.216667  0.253333  0.710000  0.253333
# 2022-04-08  0.506667  0.770000  0.313333  0.303333  0.713333  0.400000
# 2022-04-12  0.760000  0.743333  0.336667  0.360000  0.660000  0.373333
#
#                  REE       VIB
# 2022-04-05  0.260000  0.266667
# 2022-04-06  0.283333  0.243333
# 2022-04-07  0.233333  0.220000
# 2022-04-08  0.586667  0.330000
# 2022-04-12  0.683333  0.260000

# %% [markdown]
# ## Realized 5d simple return (for leader contribution scoring)

# %%
# ycols = target log-return 5 ngày
ycols = [c for c in dataset_full.columns if c.startswith("y5_")]

ret5_simple = np.exp(dataset_full[ycols]) - 1
ret5_simple.columns = [c.replace("y5_", "") for c in ret5_simple.columns]

print("✅ ret5_simple:", ret5_simple.shape, ret5_simple.index.min(), "->", ret5_simple.index.max())
# Out:
# ✅ ret5_simple: (935, 20) 2021-03-24 00:00:00 -> 2024-12-24 00:00:00

# %% [markdown]
# ## OOS Leaders 2021–2024

# %%
leader_results = {}

for yr in [2021, 2022, 2023, 2024]:
    idx = P_up_oos.index[P_up_oos.index.year == yr]  

    P = P_up_oos.loc[idx]
    R = ret5_simple.loc[idx]                          

    picks = P.idxmax(axis=1)

    contrib = pd.Series(0.0, index=P.columns)
    for t, sym in picks.items():
        contrib[sym] += R.loc[t, sym]

    leader = contrib.sort_values(ascending=False)
    leader_results[yr] = leader

    print(f"\n🏆 PREDICTED LEADER {yr} (OOS)")
    print(leader.head(5))
# Out:
# 🏆 PREDICTED LEADER 2021 (OOS)
# TCH    0.0
# GVR    0.0
# SSI    0.0
# DGC    0.0
# PDR    0.0
# dtype: float64
#
# 🏆 PREDICTED LEADER 2022 (OOS)
# DGC    1.861422
# LPB    1.265465
# EIB    1.048012
# SSI    0.717975
# MWG    0.654852
# dtype: float64
#
# 🏆 PREDICTED LEADER 2023 (OOS)
# LPB    1.185198
# SSI    1.142065
# HPG    0.674939
# NVL    0.570083
# DGC    0.550275
# dtype: float64
#
# 🏆 PREDICTED LEADER 2024 (OOS)
# DGC    1.470697
# LPB    1.416133
# STB    0.907930
# GVR    0.489571
# TCH    0.344878
# dtype: float64

# %% [markdown]
# ## Train final model on FULL sample (2021–2024)

# %%
from sklearn.ensemble import ExtraTreesClassifier

final_model = ExtraTreesClassifier(
    n_estimators=600,
    max_depth=None,
    random_state=42,
    n_jobs=-1
)

final_model.fit(X, y)
print("✅ Final ExtraTrees model trained (2021–2024)")
# Out:
# ✅ Final ExtraTrees model trained (2021–2024)

# %% [markdown]
# ## Robust ML forecast for 2025

# %%
K = 20  # số ngày cuối 2024
snapshots_2025 = X.index[-K:]

scores_2025 = pd.Series(0.0, index=[c.replace("y5cls_", "") for c in y.columns])

for d in snapshots_2025:
    X_d = X.loc[[d]]
    proba_d = final_model.predict_proba(X_d)

    P_d = pd.Series(
        [p[0,1] for p in proba_d],
        index=scores_2025.index
    )

    scores_2025 += P_d

# Trung bình xác suất
scores_2025 = (scores_2025 / K).sort_values(ascending=False)

print("🔮 ML FORECAST — LEADER SIGNALS 2025 (ROBUST)")
print(scores_2025.head(10))

print("\n🏆 PREDICTED LEADER 2025:", scores_2025.index[0])
# Out:
# 🔮 ML FORECAST — LEADER SIGNALS 2025 (ROBUST)
# KDH    0.90
# STB    0.85
# LPB    0.80
# SBT    0.75
# BCM    0.70
# SSI    0.70
# DGC    0.65
# REE    0.65
# EIB    0.65
# VIB    0.55
# dtype: float64
#
# 🏆 PREDICTED LEADER 2025: KDH

# %% [markdown]
# ## Charts with Probability

# %%
import matplotlib.pyplot as plt
import pandas as pd

def plot_price_with_signal(sym, year=2024, hi=0.6, lo=0.4):
    # Chỉ lấy 1 năm cho dễ nhìn
    idx = P_up_oos.index[P_up_oos.index.year == year]

    price = prices.loc[idx, sym]
    p_up  = P_up_oos.loc[idx, sym]

    plt.figure(figsize=(10, 4))
    plt.plot(price.index, price.values, label=f"{sym} Close Price")

    y_min, y_max = price.min(), price.max()

    # Tô nền theo tín hiệu ML
    plt.fill_between(
        price.index, y_min, y_max,
        where=(p_up > hi),
        alpha=0.15,
        label="ML signal: P(up) > 0.6"
    )

    plt.fill_between(
        price.index, y_min, y_max,
        where=(p_up < lo),
        alpha=0.15,
        label="ML signal: P(up) < 0.4"
    )

    plt.title(f"{sym} — Real Price with ML Signal ({year}, OOS)")
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
plot_price_with_signal("DGC", year=2024)
plot_price_with_signal("KDH", year=2024)
plot_price_with_signal("STB", year=2024)

# %% [markdown]
# # Predict 2026 (Volatility)

# %%
K_2026 = 60   # số ngày dùng để đo độ ổn định

snapshot_dates = X.index[-K_2026:]

print("Using snapshots from:",
      snapshot_dates.min(), "→", snapshot_dates.max())
# Out:
# Using snapshots from: 2024-10-02 00:00:00 → 2024-12-24 00:00:00

# %%
symbols = [c.replace("y5cls_", "") for c in y.columns]

P_sum = pd.Series(0.0, index=symbols)
P_sq  = pd.Series(0.0, index=symbols)

# %%
for d in snapshot_dates:
    X_d = X.loc[[d]]  # 1 snapshot

    proba = final_model.predict_proba(X_d)

    # lấy xác suất P(up) cho từng mã
    P_d = pd.Series(
        [p[0, 1] for p in proba],
        index=symbols
    )

    P_sum += P_d
    P_sq  += P_d ** 2

# %%
avg_P_up = P_sum / K_2026
std_P_up = np.sqrt(P_sq / K_2026 - avg_P_up**2)

# %%
leader_2026 = pd.DataFrame({
    "avg_P_up": avg_P_up,
    "std_P_up": std_P_up
}).sort_values(
    ["avg_P_up", "std_P_up"],
    ascending=[False, True]
)

print("🔮 ML STABILITY FORECAST — 2026")
print(leader_2026.head(10))

print("\n🏆 PREDICTED LEADER 2026:", leader_2026.index[0])
# Out:
# 🔮 ML STABILITY FORECAST — 2026
#      avg_P_up  std_P_up
# STB  0.666667  0.471405
# KDH  0.616667  0.486198
# DGC  0.600000  0.489898
# LPB  0.600000  0.489898
# BCM  0.566667  0.495536
# REE  0.516667  0.499722
# SBT  0.500000  0.500000
# HPG  0.500000  0.500000
# EIB  0.450000  0.497494
# VIB  0.450000  0.497494
#
# 🏆 PREDICTED LEADER 2026: STB

# %%
import matplotlib.pyplot as plt

df = leader_2026.copy()

plt.figure(figsize=(7, 5))

# Scatter toàn bộ cổ phiếu
plt.scatter(
    df["avg_P_up"],
    df["std_P_up"],
    alpha=0.7
)

# Annotate từng mã
for sym, row in df.iterrows():
    plt.text(
        row["avg_P_up"] + 0.002,
        row["std_P_up"] + 0.002,
        sym,
        fontsize=9
    )

# Highlight STB
plt.scatter(
    df.loc["STB", "avg_P_up"],
    df.loc["STB", "std_P_up"],
    s=150,
    edgecolors="black",
    linewidths=1.5
)
plt.text(
    df.loc["STB", "avg_P_up"],
    df.loc["STB", "std_P_up"] - 0.015,
    "STB (Leader 2026)",
    fontsize=11,
    fontweight="bold",
    ha="center"
)

plt.xlabel("Average predicted P(up)")
plt.ylabel("Std of predicted P(up)")
plt.title("Stability-based ML Forecast — Leader 2026")

plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

df = leader_2026.copy()

leader = "STB"
top_k = 5
top_syms = df.head(top_k).index.tolist()

plt.figure(figsize=(7, 5))

# Others
others = df.index.difference(top_syms)
plt.scatter(
    df.loc[others, "avg_P_up"],
    df.loc[others, "std_P_up"],
    alpha=0.4,
    label="Other stocks"
)

# Top contenders (excluding leader)
top_others = [s for s in top_syms if s != leader]
plt.scatter(
    df.loc[top_others, "avg_P_up"],
    df.loc[top_others, "std_P_up"],
    s=90,
    alpha=0.8,
    label="Top contenders"
)

# Leader
plt.scatter(
    df.loc[leader, "avg_P_up"],
    df.loc[leader, "std_P_up"],
    s=180,
    marker="*",
    edgecolors="black",
    linewidths=1.5,
    label="Leader 2026 (STB)"
)

plt.xlabel("Average predicted P(up)")
plt.ylabel("Std of predicted P(up)")
plt.title("Stability-based ML Forecast — Leader 2026")

plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
