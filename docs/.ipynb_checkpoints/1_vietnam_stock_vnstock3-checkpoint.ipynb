# %% [markdown]
# <div style="border:2px solid #ffc107; background:#fffde7; border-radius:8px; padding:16px; margin:16px 0;">
#   <p style="display:flex; align-items:center; margin-bottom:10px;">
#     <span style="font-size:26px; color:#e65100; margin-right:10px;">⚠️</span>
#     <span style="font-size:18px; font-weight:700; color:#b26a00;">CẢNH BÁO: Google Colab hiện đang chặn IP từ Vietcap, không sử dụng được!</span>
#   </p>
#   <ul style="font-size:16px; color:#333; margin-left:38px; margin-top:0;">
#     <li><span style="color:#1976d2; font-weight:600;">Ưu tiên 1:</span> Hãy dùng <b>GitHub Codespaces</b> để chạy thử <code>vnstock</code> nhanh nhất. Cần có tài khoản Github</li>
#     <li><span style="color:#0057c7; font-weight:600;">Ưu tiên 2:</span> Có thể thử tiếp với <b>Deepnote</b> khi cần trải nghiệm chia sẻ. Đăng nhập bằng Google để sử dụng.</li>
#     <li><span style="color:#d32f2f; text-decoration:line-through;">Colab</span> <span style="color:#d32f2f;">(đang bị chặn IP, không phù hợp hiện tại)</span></li>
#   </ul>
#   <p style="margin-top:12px; color:#b26a00;">
#     Vui lòng chọn phương án thay thế theo thứ tự trên để đảm bảo truy cập không bị gián đoạn khi thử nghiệm hoặc cài đầy đủ môi trường Python trên máy.
#   </p>
# </div>

# %% [markdown]
# <p>
#   <a href="https://codespaces.new/thinh-vu/vnstock" target="_blank" style="display:inline-block; vertical-align:middle;">
#     <img src="https://img.shields.io/badge/Open%20in-GitHub%20Codespaces-blue?logo=github" alt="Open in GitHub Codespaces" style="height:20px; vertical-align:middle;">
#   </a>
#   <a href="https://deepnote.com/workspace/Vnstockscom-3ff51cb7-3b7c-4cf5-b082-182b28b9b623/project/Vnstock-Demo-Notebooks-42230c88-0071-4aca-bfc1-70a5374f2371/notebook/1vietnamstockvnstock-9d4dd94bfd5b42a09b2fc8175ffd4408?utm_source=share-modal&utm_medium=product-shared-content&utm_campaign=notebook&utm_content=42230c88-0071-4aca-bfc1-70a5374f2371" target="_blank" style="display:inline-block; vertical-align:middle; margin-left:8px;">
#     <img src="https://deepnote.com/favicon.ico" alt="Deepnote" style="height:22px; vertical-align:middle; border-radius:4px; margin-right:6px;">
#     <span style="font-size:16px; font-weight:500; vertical-align:middle; color:#222222;">Open in Deepnote</span>
#   </a>
#   <a href="https://colab.research.google.com/github/thinh-vu/vnstock/blob/main/docs/1_vietnam_stock_vnstock3.ipynb" target="_blank" style="display:inline-block; vertical-align:middle; margin-left:8px;">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" style="height:20px; vertical-align:middle;">
#   </a>
# </p>

# %% [markdown]
# # Mục lục

# %% [markdown]
# # I. Cài đặt

# %% [markdown]
# ## Cài đặt thư viện

# %%
# !pip install git+https://github.com/thinh-vu/vnstock
# Out:
# Collecting git+https://github.com/thinh-vu/vnstock
#   Cloning https://github.com/thinh-vu/vnstock to /tmp/pip-req-build-3tjfymqe
#   Running command git clone --filter=blob:none --quiet https://github.com/thinh-vu/vnstock /tmp/pip-req-build-3tjfymqe
#   Resolved https://github.com/thinh-vu/vnstock to commit 7bc8ec5eeda5c107995975d985306405ccbc512e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (4.14.2)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (2.2.1)
# Requirement already satisfied: seaborn in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (0.13.2)
# Requirement already satisfied: openpyxl in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (3.1.2)
# Requirement already satisfied: pydantic in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (2.12.4)
# Requirement already satisfied: psutil in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (6.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (25.0)
# Requirement already satisfied: importlib-metadata>=1.0 in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (8.7.0)
# Requirement already satisfied: tenacity in /home/codespace/.local/lib/python3.12/site-packages (from vnstock==3.2.7) (9.1.2)
# Requirement already satisfied: vnai>=2.2.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from vnstock==3.2.7) (2.2.3)
# Requirement already satisfied: vnstock_ezchart>=0.0.3 in /home/codespace/.python/current/lib/python3.12/site-packages (from vnstock==3.2.7) (0.0.3)
# Requirement already satisfied: zipp>=3.20 in /home/codespace/.local/lib/python3.12/site-packages (from importlib-metadata>=1.0->vnstock==3.2.7) (3.23.0)
# Requirement already satisfied: cffi>=1.17.1 in /home/codespace/.local/lib/python3.12/site-packages (from vnai>=2.2.2->vnstock==3.2.7) (2.0.0)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.17.1->vnai>=2.2.2->vnstock==3.2.7) (2.23)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock==3.2.7) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock==3.2.7) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock==3.2.7) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->vnstock==3.2.7) (2025.7.9)
# Requirement already satisfied: squarify in /home/codespace/.local/lib/python3.12/site-packages (from vnstock_ezchart>=0.0.3->vnstock==3.2.7) (0.4.4)
# Requirement already satisfied: wordcloud in /home/codespace/.local/lib/python3.12/site-packages (from vnstock_ezchart>=0.0.3->vnstock==3.2.7) (1.9.4)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4->vnstock==3.2.7) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4->vnstock==3.2.7) (4.15.0)
# Requirement already satisfied: et-xmlfile in /home/codespace/.local/lib/python3.12/site-packages (from openpyxl->vnstock==3.2.7) (2.0.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock==3.2.7) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock==3.2.7) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock==3.2.7) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->vnstock==3.2.7) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->vnstock==3.2.7) (1.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic->vnstock==3.2.7) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic->vnstock==3.2.7) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic->vnstock==3.2.7) (0.4.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/codespace/.local/lib/python3.12/site-packages (from seaborn->vnstock==3.2.7) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock==3.2.7) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock==3.2.7) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock==3.2.7) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock==3.2.7) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock==3.2.7) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->vnstock==3.2.7) (3.2.5)

# %% [markdown]
# 1. Chứng khoán Việt Nam [tại đây](https://colab.research.google.com/github/thinh-vu/vnstock/blob/main/docs/1_vietnam_stock_vnstock3.ipynb)
# 2. Chứng khoán quốc tế: Forex, Crypto, Chỉ số [tại đây](https://colab.research.google.com/github/thinh-vu/vnstock/blob/main/docs/2_international_market.ipynb)
# 3. Dữ liệu Thị trường, hàng hoá [tại đây](https://colab.research.google.com/github/thinh-vu/vnstock/blob/main/docs/3_commodities_vnstock3.ipynb)
# 4. Biểu diễn dữ liệu trực quan từ Vnstock3 [tại đây](https://colab.research.google.com/github/thinh-vu/vnstock/blob/main/docs/5_visualization_data_exploration_vnstock3.ipynb)

# %% [markdown]
# ## Nạp thư viện lần đầu

# %% [markdown]
# > Bạn có thể nạp toàn bộ các module của thư viện vào môi trường làm việc nếu chưa biết rõ mình cần gì hoặc chọn từng module riêng biệt để nạp vào khi đã quen thuộc.

# %%
## Có thể gọi các class chi tiết trong thư viện thay vì sử dụng cấp cao nhất là Vnstock
from vnstock import Listing, Company, Finance, Trading, Screener
# Out:
# Non-200 response fetching content: 502
# ## 👋 Chào mừng bạn đến với Vnstock!
# Cảm ơn bạn đã sử dụng package phân tích chứng khoán #1 tại Việt Nam
# * Tài liệu: [Sổ tay hướng dẫn](https://vnstocks.com/docs)
# * Cộng đồng: [Nhóm Facebook](https://facebook.com/groups/vnstock.official)
# Khám phá các tính năng mới nhất và tham gia cộng đồng để nhận hỗ trợ.

# %% [markdown]
# Bạn cũng có thể gọi các class trong theo vị trí chi tiết của nguồn dữ liệu
#
# ```python
# from vnstock.explorer.vci import Listing, Quote, Company, Finance, Trading
# ```
#
# hoặc
# ```python
# from vnstock.explorer.tcbs import Quote, Company, Finance, Trading, Screener
# ```

# %% [markdown]
# # II. Truy xuất dữ liệu - CK Việt Nam

# %% [markdown]
# * Khởi tạo đối tượng stock để dùng cho tất cả thao tác truy xuất dữ liệu chứng khoán về sau. Luồng công việc minh hoạ dưới đây giả định bạn bắt đầu với 1 mã chứng khoán cần phân tích, mặc định là VN30F1M. Bạn có thể thay đổi sang mã bất kỳ bằng cách nhập tham số `symbol` tại hàm chức năng thay vì khởi tạo lại đối tượng. Ví dụ, mã `VN30F1M` được gán khi tạo đối tượng, nhưng khi gọi dữ liệu giá lịch sử, bạn có thể cập nhật mã mới là `ACB` thay vì khởi tạo lại đối tượng một cách bất tiện: `stock.quote.history(symbol='ACB', start='2020-01-01', end='2024-12-31')`
#
# * Chọn nguồn dữ liệu thuộc danh sách được hỗ trợ: VCI, TCBS cho chứng khoán trong nước, MSN cho dữ liệu chứng khoán quốc tế và sàn HOSE.

# %% [markdown]
# ## Listing: Liệt kê danh sách chứng khoán

# %%
# VCI là nguồn dữ liệu từ CK Vietcap bên cạnh nguồn từ TCBS
from vnstock import Listing
listing = Listing()

# %% [markdown]
# ### Danh sách tất cả mã CK niêm yết (đơn giản)

# %%
listing.all_symbols()
# Out:
#      symbol                                         organ_name
# 0       YTC  Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...
# 1       YEG                     Công ty Cổ phần Tập đoàn Yeah1
# 2       YBM     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
# 3       YBC      Công ty Cổ phần Xi măng và Khoáng sản Yên Bái
# 4       XPH                    Công ty Cổ phần Xà phòng Hà Nội
# ...     ...                                                ...
# 1722    AAS            Công ty Cổ phần Chứng khoán SmartInvest
# 1723    AAM                    Công ty Cổ Phần Thủy Sản MeKong
# 1724    AAH                           Công ty Cổ phần Hợp Nhất
# 1725    AAA                  Công ty Cổ phần Nhựa An Phát Xanh
# 1726    A32                                 Công ty Cổ phần 32
#
# [1727 rows x 2 columns]

# %% [markdown]
# ### Liệt kê mã CP theo sàn (đầy đủ)

# %%
# Dữ liệu bao gồm tất cả các mã không kể đang niêm yết hay không
listing.symbols_by_exchange()
# Out:
#          symbol  exchange   type                          organ_short_name  \
# 0           YTC     UPCOM  STOCK                           XNK Y tế TP.HCM
# 1           YEG       HSX  STOCK                            Tập đoàn Yeah1
# 2           YBM       HSX  STOCK                     Khoáng sản CN Yên Bái
# 3           YBC     UPCOM  STOCK             Xi măng và Khoáng sản Yên Bái
# 4           XPH     UPCOM  STOCK                           Xà phòng Hà Nội
# ...         ...       ...    ...                                       ...
# 3136  41I1F7000  DELISTED     FU                          41I1F7000 - HĐTL
# 3137  41BAG6000       HNX     FU  10-year Government Bond   Futures 062026
# 3138  41BAG3000       HNX     FU  10-year Government Bond   Futures 032026
# 3139  41B5G6000       HNX     FU  5-year Government Bond    Futures 062026
# 3140  41B5G3000       HNX     FU  5-year Government Bond    Futures 032026
#
#                                              organ_name product_grp_id
# 0     Công ty Cổ phần Xuất nhập khẩu Y tế Thành phố ...            UPX
# 1                        Công ty Cổ phần Tập đoàn Yeah1            STO
# 2        Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái            STO
# 3         Công ty Cổ phần Xi măng và Khoáng sản Yên Bái            UPX
# 4                       Công ty Cổ phần Xà phòng Hà Nội            UPX
# ...                                                 ...            ...
# 3136                                   41I1F7000 - HĐTL            FIO
# 3137           10-year Government Bond   Futures 062026            FBX
# 3138           10-year Government Bond   Futures 032026            FBX
# 3139           5-year Government Bond    Futures 062026            FBX
# 3140           5-year Government Bond    Futures 032026            FBX
#
# [3141 rows x 6 columns]

# %% [markdown]
# ### Liệt kê mã CP theo ngành icb

# %%
listing.symbols_by_industries()
# Out:
#      symbol                                         organ_name  \
# 0       BQP     Công ty Cổ phần Nhựa chất lượng cao Bình Thuận
# 1       F88                         Công ty Cổ phần Đầu tư F88
# 2       DVT  Trung tâm Đào tạo nghiệp vụ Giao thông vận tải...
# 3       ABS     Công ty Cổ phần Dịch vụ Nông nghiệp Bình Thuận
# 4       AFX  Công ty Cổ phần Xuất Nhập khẩu Nông sản Thực p...
# ...     ...                                                ...
# 1579    XHC                  Công ty Cổ phần Xuân Hòa Việt Nam
# 1580    XMP                Công ty Cổ phần Thủy điện Xuân Minh
# 1581    YBC      Công ty Cổ phần Xi măng và Khoáng sản Yên Bái
# 1582    YBM     Công ty Cổ phần Khoáng sản Công nghiệp Yên Bái
# 1583    YEG                     Công ty Cổ phần Tập đoàn Yeah1
#
#                             icb_name3                      icb_name2  \
# 0                            Hóa chất                       Hóa chất
# 1                   Dịch vụ tài chính              Dịch vụ tài chính
# 2          Tư vấn & Hỗ trợ Kinh doanh     Hàng & Dịch vụ Công nghiệp
# 3                            Hóa chất                       Hóa chất
# 4     Phân phối thực phẩm & dược phẩm                         Bán lẻ
# ...                               ...                            ...
# 1579                    Hàng gia dụng        Hàng cá nhân & Gia dụng
# 1580        Sản xuất & Phân phối Điện  Điện, nước & xăng dầu khí đốt
# 1581             Xây dựng và Vật liệu           Xây dựng và Vật liệu
# 1582                      Khai khoáng              Tài nguyên Cơ bản
# 1583                     Truyền thông                   Truyền thông
#
#                                         icb_name4 com_type_code icb_code1  \
# 0                              Nhựa, cao su & sợi            CT      1000
# 1                               Tài chính cá nhân            CT      8000
# 2                              Đào tạo & Việc làm            CT      2000
# 3     Sản phẩm hóa dầu, Nông dược & Hóa chất khác            CT      1000
# 4                             Phân phối thực phẩm            CT      5000
# ...                                           ...           ...       ...
# 1579                            Thiết bị gia dụng            CT      3000
# 1580                    Sản xuất & Phân phối Điện            CT      7000
# 1581                 Vật liệu xây dựng & Nội thất            CT      2000
# 1582                                  Khai khoáng            CT      1000
# 1583                      Giải trí & Truyền thông            CT      5000
#
#      icb_code2 icb_code3 icb_code4
# 0         1300      1350      1353
# 1         8700      8770      8773
# 2         2700      2790      2793
# 3         1300      1350      1357
# 4         5300      5330      5337
# ...        ...       ...       ...
# 1579      3700      3720      3726
# 1580      7500      7530      7535
# 1581      2300      2350      2353
# 1582      1700      1770      1775
# 1583      5500      5550      5553
#
# [1584 rows x 10 columns]

# %% [markdown]
# ### Danh sách cổ phiếu theo nhóm

# %%
# Liệt kê tất cả mã chứng khoán theo nhóm phân loại. Ví dụ HOSE, VN30, VNMidCap, VNSmallCap, VNAllShare, VN100, ETF, HNX, HNX30, HNXCon, HNXFin, HNXLCap, HNXMSCap, HNXMan, UPCOM, FU_INDEX (mã chỉ số hợp đồng tương lai), CW (chứng quyền)
listing.symbols_by_group('VN30')
# Out:
# 0     ACB
# 1     BCM
# 2     BID
# 3     CTG
# 4     DGC
# 5     FPT
# 6     GAS
# 7     GVR
# 8     HDB
# 9     HPG
# 10    LPB
# 11    MBB
# 12    MSN
# 13    MWG
# 14    PLX
# 15    SAB
# 16    SHB
# 17    SSB
# 18    SSI
# 19    STB
# 20    TCB
# 21    TPB
# 22    VCB
# 23    VHM
# 24    VIB
# 25    VIC
# 26    VJC
# 27    VNM
# 28    VPB
# 29    VRE
# Name: symbol, dtype: object

# %% [markdown]
# ### Danh sách mã ngành theo mã icb

# %%
listing.industries_icb()
# Out:
#                                    icb_name  \
# 0                          Sản xuất Dầu khí
# 1    Thiết bị, Dịch vụ và Phân phối Dầu khí
# 2                                  Hóa chất
# 3                        Lâm nghiệp và Giấy
# 4                                  Kim loại
# ..                                      ...
# 150                              Viễn thông
# 151                      Tiện ích Cộng đồng
# 152                               Tài chính
# 153                               Ngân hàng
# 154                     Công nghệ Thông tin
#
#                                 en_icb_name icb_code  level
# 0                       Oil & Gas Producers     0530      3
# 1    Oil Equipment, Services & Distribution     0570      3
# 2                                 Chemicals     1350      3
# 3                          Forestry & Paper     1730      3
# 4                Industrial Metals & Mining     1750      3
# ..                                      ...      ...    ...
# 150                      Telecommunications     6000      1
# 151                               Utilities     7000      1
# 152                              Financials     8000      1
# 153                                   Banks     8301      1
# 154                              Technology     9000      1
#
# [155 rows x 4 columns]

# %% [markdown]
# ## Quote: Giá chứng khoán

# %%
from vnstock import Quote
quote = Quote(symbol='VN30', source='TCBS')

# %% [markdown]
# #### Giá lịch sử

# %% [markdown]
# ##### Cổ phiếu

# %%
quote.history(symbol='', start='2012-02-06', end='2025-03-19', interval='1D')
# Out:
#            time     open     high      low    close     volume
# 0    2012-02-07   449.31   449.31   449.31   449.31   17261070
# 1    2012-02-08   460.98   460.98   460.98   460.98   20406280
# 2    2012-02-09   464.73   464.73   464.73   464.73   20379320
# 3    2012-02-10   458.23   458.23   458.23   458.23   20816360
# 4    2012-02-13   446.23   446.23   446.23   446.23   13169260
# ...         ...      ...      ...      ...      ...        ...
# 3495 2025-03-13  1393.93  1400.60  1385.24  1387.30  348831063
# 3496 2025-03-14  1387.08  1394.39  1385.20  1387.03  374746690
# 3497 2025-03-17  1392.75  1397.28  1389.42  1394.90  352390462
# 3498 2025-03-18  1398.44  1400.38  1388.64  1388.64  291777344
# 3499 2025-03-19  1385.92  1386.57  1374.83  1377.63  363636853
#
# [3500 rows x 6 columns]

# %%
df = quote.history(
    symbol='VN30',
    start='2012-02-06',
    end='2025-11-09',
    interval='1D'
)
df.to_excel('VN30_history_2012_2025.xlsx', index=False)
print("Đã lưu file thành công!")
# Out:
# Đã lưu file thành công!

# %% [markdown]
# # Cổ phiếu Project

# %%
# ACB
quote = Quote(symbol='ACB', source='TCBS')
quote.history(symbol='', start='2020-01-01', end='2025-11-10', interval='1D')
# Out:
#            time   open   high    low  close    volume
# 3    2020-01-02   6.58   6.64   6.55   6.64   1163109
# 4    2020-01-03   6.64   6.70   6.61   6.64   1055528
# 5    2020-01-06   6.64   6.64   6.49   6.49   1286035
# 6    2020-01-07   6.49   6.55   6.49   6.49   1050934
# 7    2020-01-08   6.49   6.49   6.35   6.38   2304937
# ...         ...    ...    ...    ...    ...       ...
# 1495 2025-11-04  25.45  26.10  25.40  26.00  17988658
# 1496 2025-11-05  25.80  25.90  25.55  25.60   6234065
# 1497 2025-11-06  25.55  25.70  25.30  25.30   6532302
# 1498 2025-11-07  25.25  25.30  24.85  24.90  12120670
# 1499 2025-11-10  24.90  25.20  24.70  24.80   7222700
#
# [1497 rows x 6 columns]

# %%
df = quote.history(symbol='', start='2020-01-01', end='2025-11-10', interval='1D')
df.to_excel('ACB_2020_2025.xlsx', index=False)
print("Đã lưu file thành công!")
# Out:
# Đã lưu file thành công!

# %% [markdown]
# ##### Hợp đồng tương lai

# %%
quote.history(symbol='VN30F1M', start='2024-01-02', end='2025-03-19', interval='1D')
# Out:
#           time     open     high      low    close     volume
# 0   2024-01-02  1137.11  1140.11  1129.78  1131.64  184210752
# 1   2024-01-03  1131.57  1144.85  1126.57  1144.85  179565525
# 2   2024-01-04  1145.72  1167.27  1144.57  1156.37  422364989
# 3   2024-01-05  1156.71  1161.53  1152.79  1161.14  229464256
# 4   2024-01-08  1164.43  1169.95  1159.73  1163.52  234279491
# ..         ...      ...      ...      ...      ...        ...
# 495 2025-03-13  1393.93  1400.60  1385.24  1387.30  348831063
# 496 2025-03-14  1387.08  1394.39  1385.20  1387.03  374746690
# 497 2025-03-17  1392.75  1397.28  1389.42  1394.90  352390462
# 498 2025-03-18  1398.44  1400.38  1388.64  1388.64  291777344
# 499 2025-03-19  1385.92  1386.57  1374.83  1377.63  363636853
#
# [500 rows x 6 columns]

# %%
quote.history(symbol='VN30F2411', start='2024-01-02', end='2025-03-19', interval='1D')
# Out:
#           time     open     high      low    close     volume
# 0   2024-01-02  1137.11  1140.11  1129.78  1131.64  184210752
# 1   2024-01-03  1131.57  1144.85  1126.57  1144.85  179565525
# 2   2024-01-04  1145.72  1167.27  1144.57  1156.37  422364989
# 3   2024-01-05  1156.71  1161.53  1152.79  1161.14  229464256
# 4   2024-01-08  1164.43  1169.95  1159.73  1163.52  234279491
# ..         ...      ...      ...      ...      ...        ...
# 495 2025-03-13  1393.93  1400.60  1385.24  1387.30  348831063
# 496 2025-03-14  1387.08  1394.39  1385.20  1387.03  374746690
# 497 2025-03-17  1392.75  1397.28  1389.42  1394.90  352390462
# 498 2025-03-18  1398.44  1400.38  1388.64  1388.64  291777344
# 499 2025-03-19  1385.92  1386.57  1374.83  1377.63  363636853
#
# [500 rows x 6 columns]

# %% [markdown]
# ##### Chỉ số

# %%
quote.history(symbol='VNINDEX', start='2024-01-02', end='2025-03-19', interval='1D')
# Out:
#           time     open     high      low    close     volume
# 0   2024-01-02  1137.11  1140.11  1129.78  1131.64  184210752
# 1   2024-01-03  1131.57  1144.85  1126.57  1144.85  179565525
# 2   2024-01-04  1145.72  1167.27  1144.57  1156.37  422364989
# 3   2024-01-05  1156.71  1161.53  1152.79  1161.14  229464256
# 4   2024-01-08  1164.43  1169.95  1159.73  1163.52  234279491
# ..         ...      ...      ...      ...      ...        ...
# 495 2025-03-13  1393.93  1400.60  1385.24  1387.30  348831063
# 496 2025-03-14  1387.08  1394.39  1385.20  1387.03  374746690
# 497 2025-03-17  1392.75  1397.28  1389.42  1394.90  352390462
# 498 2025-03-18  1398.44  1400.38  1388.64  1388.64  291777344
# 499 2025-03-19  1385.92  1386.57  1374.83  1377.63  363636853
#
# [500 rows x 6 columns]

# %%
quote.history(symbol='HNXINDEX', start='2024-01-02', end='2025-03-19', interval='1D')
# Out:
#           time     open     high      low    close     volume
# 0   2024-01-02  1137.11  1140.11  1129.78  1131.64  184210752
# 1   2024-01-03  1131.57  1144.85  1126.57  1144.85  179565525
# 2   2024-01-04  1145.72  1167.27  1144.57  1156.37  422364989
# 3   2024-01-05  1156.71  1161.53  1152.79  1161.14  229464256
# 4   2024-01-08  1164.43  1169.95  1159.73  1163.52  234279491
# ..         ...      ...      ...      ...      ...        ...
# 495 2025-03-13  1393.93  1400.60  1385.24  1387.30  348831063
# 496 2025-03-14  1387.08  1394.39  1385.20  1387.03  374746690
# 497 2025-03-17  1392.75  1397.28  1389.42  1394.90  352390462
# 498 2025-03-18  1398.44  1400.38  1388.64  1388.64  291777344
# 499 2025-03-19  1385.92  1386.57  1374.83  1377.63  363636853
#
# [500 rows x 6 columns]

# %%
quote.history(symbol='UPCOMINDEX', start='2024-01-02', end='2025-03-19', interval='1D')
# Out:
#           time     open     high      low    close     volume
# 0   2024-01-02  1137.11  1140.11  1129.78  1131.64  184210752
# 1   2024-01-03  1131.57  1144.85  1126.57  1144.85  179565525
# 2   2024-01-04  1145.72  1167.27  1144.57  1156.37  422364989
# 3   2024-01-05  1156.71  1161.53  1152.79  1161.14  229464256
# 4   2024-01-08  1164.43  1169.95  1159.73  1163.52  234279491
# ..         ...      ...      ...      ...      ...        ...
# 495 2025-03-13  1393.93  1400.60  1385.24  1387.30  348831063
# 496 2025-03-14  1387.08  1394.39  1385.20  1387.03  374746690
# 497 2025-03-17  1392.75  1397.28  1389.42  1394.90  352390462
# 498 2025-03-18  1398.44  1400.38  1388.64  1388.64  291777344
# 499 2025-03-19  1385.92  1386.57  1374.83  1377.63  363636853
#
# [500 rows x 6 columns]

# %% [markdown]
# ##### Chứng quyền

# %%
quote.history(symbol='CFPT2314', start='2024-01-02', end='2025-03-19', interval='1D')
# Out:
#           time     open     high      low    close     volume
# 0   2024-01-02  1137.11  1140.11  1129.78  1131.64  184210752
# 1   2024-01-03  1131.57  1144.85  1126.57  1144.85  179565525
# 2   2024-01-04  1145.72  1167.27  1144.57  1156.37  422364989
# 3   2024-01-05  1156.71  1161.53  1152.79  1161.14  229464256
# 4   2024-01-08  1164.43  1169.95  1159.73  1163.52  234279491
# ..         ...      ...      ...      ...      ...        ...
# 495 2025-03-13  1393.93  1400.60  1385.24  1387.30  348831063
# 496 2025-03-14  1387.08  1394.39  1385.20  1387.03  374746690
# 497 2025-03-17  1392.75  1397.28  1389.42  1394.90  352390462
# 498 2025-03-18  1398.44  1400.38  1388.64  1388.64  291777344
# 499 2025-03-19  1385.92  1386.57  1374.83  1377.63  363636853
#
# [500 rows x 6 columns]

# %% [markdown]
# ##### Trái phiếu niêm yết

# %%
quote.history(symbol='CII424002', start='2024-01-02', end='2025-03-19', interval='1D')
# Out:
#           time     open     high      low    close     volume
# 0   2024-01-02  1137.11  1140.11  1129.78  1131.64  184210752
# 1   2024-01-03  1131.57  1144.85  1126.57  1144.85  179565525
# 2   2024-01-04  1145.72  1167.27  1144.57  1156.37  422364989
# 3   2024-01-05  1156.71  1161.53  1152.79  1161.14  229464256
# 4   2024-01-08  1164.43  1169.95  1159.73  1163.52  234279491
# ..         ...      ...      ...      ...      ...        ...
# 495 2025-03-13  1393.93  1400.60  1385.24  1387.30  348831063
# 496 2025-03-14  1387.08  1394.39  1385.20  1387.03  374746690
# 497 2025-03-17  1392.75  1397.28  1389.42  1394.90  352390462
# 498 2025-03-18  1398.44  1400.38  1388.64  1388.64  291777344
# 499 2025-03-19  1385.92  1386.57  1374.83  1377.63  363636853
#
# [500 rows x 6 columns]

# %% [markdown]
# #### Intraday: dữ liệu khớp lệnh

# %%
# Dữ liệu khớp lệnh trong ngày giao dịch realtime hoặc ngày gần nhất (ngoài giờ giao dịch)
quote.intraday(symbol='ACB', page_size=10_000, show_log=False)
# Out:
# Empty DataFrame
# Columns: [time, price, volume, match_type]
# Index: []

# %%
# Bước giá và khối lượng giao dịch: realtime
quote.price_depth('ACB')

# %% [markdown]
# ## Trading: Giao dịch

# %%
from vnstock import Trading
trading = Trading(source='VCI')

# %% [markdown]
# ### Bảng giá

# %%
trading.price_board(['ACB'])

# %%
trading.price_board(['VCB','ACB','TCB','BID']).T # Bỏ .T để xoay trở lại đúng kiểu hiển thị bảng giá

# %% [markdown]
# ## Company: Thông tin công ty

# %% [markdown]
# > Đã bổ sung nguồn dữ liệu từ VCI từ bản Vnstock3.2.0

# %% [markdown]
# ### New - VCI

# %%
from vnstock import Company
company = Company(symbol='ACB', source='VCI')

# %% [markdown]
# Loại bỏ đoạn mã `.head()` để xem toàn bộ dữ liệu thay vì chỉ lấy 5 dòng đầu tiên.

# %% [markdown]
# #### Hồ sơ

# %%
company.overview()

# %% [markdown]
# #### Cổ đông

# %%
company.shareholders()

# %% [markdown]
# #### Công ty con

# %%
company.subsidiaries()

# %% [markdown]
# #### Công ty liên kết

# %%
# Phương thức này không có trong nguồn TCBS
company.affiliate()

# %% [markdown]
# #### Lãnh đạo

# %%
company.officers(filter_by='working').head() # filter_by='all' hoặc 'working' hoặc 'resigned'

# %% [markdown]
# #### Tin tức

# %%
company.news().head(3)

# %% [markdown]
# #### Sự kiện

# %%
company.events().head(3)

# %% [markdown]
# #### Báo cáo phân tích

# %%
company.reports()

# %% [markdown]
# #### Tình hình tài chính

# %%
company.ratio_summary()

# %% [markdown]
# #### Thống kê giao dịch

# %%
company.trading_stats()

# %% [markdown]
# ### TCBS

# %%
from vnstock import Vnstock

company = Vnstock().stock(symbol='VCB', source='TCBS').company

# %% [markdown]
# #### Tổng quan

# %%
company.overview()

# %% [markdown]
# #### Hồ sơ

# %%
company.profile()

# %% [markdown]
# #### Cổ đông

# %%
company.shareholders()

# %% [markdown]
# #### Giao dịch nội bộ

# %%
company.insider_deals().head(3)

# %% [markdown]
# #### Công ty con, liên kết

# %%
company.subsidiaries().head()

# %% [markdown]
# #### Ban lãnh đạo

# %%
company.officers().head()

# %% [markdown]
# #### Sự kiện

# %%
company.events().head()

# %% [markdown]
# #### Tin tức

# %%
company.news().head()

# %% [markdown]
# #### Cổ tức

# %%
company.dividends().head()

# %% [markdown]
# ## Finance: Báo cáo tài chính

# %%
from vnstock import Finance
finance = Finance(symbol='ACB', source='VCI')

# %% [markdown]
# ### Bảng cân đối kế toán

# %%
finance.balance_sheet(period='year', lang='vi', dropna=True)

# %%
finance.balance_sheet(period='quarter', lang='en', dropna=True).head()

# %% [markdown]
# ### Báo cáo lãi lỗ

# %%
finance.income_statement(period='year', lang='vi', dropna=True).head()

# %%
finance.income_statement(period='quarter', lang='en', dropna=True).head()

# %% [markdown]
# ### Báo cáo lưu chuyển tiền tệ

# %%
finance.cash_flow(period='year', dropna=True).head()

# %%
finance.income_statement(period='quarter', lang='en', dropna=True).head()

# %% [markdown]
# ### Chỉ số tài chính

# %%
finance.ratio(period='year', lang='vi', dropna=True).head()

# %%
finance.ratio(period='quarter', lang='en', dropna=True).head()

# %% [markdown]
# ## New - Bộ lọc cổ phiếu

# %% [markdown]
# Hàm này chỉ tồn tại với nguồn dữ liệu TCBS

# %%
from vnstock import Screener

screener = Screener()
screener_df = screener.stock(params={"exchangeName": "HOSE,HNX,UPCOM"}, limit=1700)
screener_df

# %%
from vnstock import Vnstock
import pandas as pd
from tqdm import tqdm
import time
import os

# 3️⃣ Hàm lấy dữ liệu toàn bộ VN30
def fetch_vn30_open_close_volume(start='2012-02-06', end='2025-11-09',
                                 source='VCI', interval='1D',
                                 out_file='VN30_open_close_volume_2012_2025.xlsx',
                                 sleep_sec=0.3):
    """
    Lấy dữ liệu open, close, volume của tất cả cổ phiếu trong nhóm VN30.
    Trả về DataFrame và lưu ra file Excel.
    """
    vnstock_obj = Vnstock()
    listing = vnstock_obj.stock(source=source).listing

    # Lấy danh sách mã thuộc nhóm VN30 (Series)
    vn30_symbols = listing.symbols_by_group('VN30').tolist()

    combined = []

    for sym in tqdm(vn30_symbols, desc='Fetching VN30 data'):
        try:
            quote = vnstock_obj.stock(symbol=sym, source=source).quote
            df = quote.history(start=start, end=end, interval=interval, to_df=True)
            
            if df is None or len(df) == 0:
                continue
            
            # Giữ lại cột time, open, close, volume
            df = df[['time', 'open', 'close', 'volume']]
            df['symbol'] = sym

            combined.append(df)
            time.sleep(sleep_sec)

        except Exception as e:
            print(f"⚠️ Lỗi khi lấy {sym}: {e}")

    # Gộp tất cả lại
    all_df = pd.concat(combined, ignore_index=True)
    all_df['time'] = pd.to_datetime(all_df['time'])
    all_df = all_df.sort_values(['symbol', 'time']).reset_index(drop=True)

    # Lưu ra file Excel
    all_df.to_excel(out_file, index=False)
    print(f"✅ Đã lưu dữ liệu vào file: {out_file}")
    return all_df


# 4️⃣ Chạy hàm
df_vn30 = fetch_vn30_open_close_volume(
    start='2012-02-06',
    end='2025-11-09',
    source='VCI',      # Ưu tiên nguồn VCI
    interval='1D',
    out_file='VN30_open_close_volume_2012_2025.xlsx',
    sleep_sec=0.25
)

# 5️⃣ Kiểm tra vài dòng đầu
df_vn30.head()
# Out:
# Non-200 response fetching content: 502
# ## 👋 Chào mừng bạn đến với Vnstock!
# Cảm ơn bạn đã sử dụng package phân tích chứng khoán #1 tại Việt Nam
# * Tài liệu: [Sổ tay hướng dẫn](https://vnstocks.com/docs)
# * Cộng đồng: [Nhóm Facebook](https://facebook.com/groups/vnstock.official)
# Khám phá các tính năng mới nhất và tham gia cộng đồng để nhận hỗ trợ.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from vnstock import Vnstock
#       2 import pandas as pd
# ----> 3 from tqdm import tqdm
#       4 import time
#       5 import os
#
# ModuleNotFoundError: No module named 'tqdm'
